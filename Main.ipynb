# %% [markdown]
# # цели и задачи проекта;
# Цель проекта: увеличить эффективность работы менеджеров, за счет нового подхода к отбору объектов недвижимости для анализа, что увеличит рабочее время на более выгодные предложения на рынке
#
# Задачи проекта:
# 1) Создать модели классификации и ранжирования недвижимости;
# 2) Должно быть разработано несколько моделей в зависимости от цели поиска недвижимости;
#
# # поэтапное описание работы;
# 1) Анализ датасета;
# 2) Разработка вариантов преобразования датасета;
# 3) Проверка преобразования на полноту и точность;
# 4) Изучение общепринятых критериев оценки недвижимости;
# 5) Построение подели на выявленных критериях и попытки формулировки цели поиска недвижимости;
# 6) Проверка модели;
# 7) Проба вариантов изменения критериев;
# 8) Принятие решение о итоговой моделях;
#
# # промежуточные выводы;
# 1) В Датасете надо чистить все поля;
# 2) Поле "homeFacts" не является валидным JSON;
# 3) Попытки бороться с полем цены:
#     '+'
#     '\m'
# 4) Площади недвижимости мало значений - колонку не учитываем;
#
#
# # основные итоги работы.

# %% [markdown]
# # Предполагается наличие файла data 2.csv в папке с проектом

# %%
#иморты
import pandas as pd
import json
import re

# %%
#функции

#преобразование цены в число, убираем $ и запятые
def convTarget(s):
    if isinstance(s, str) and s != '':
        s = s.replace(',','')
        if len(s)>4 and s[-4] == 'sqft':
            s = s[:-4]
        if s[0] == '$':
            s = s[1:]
        if len(s)>2 and s[-2:] == '/m':
            s = s[:-2]
        if len(s)>3 and s[-3:] == '/mo':
            s = s[:-3]
        if s[-1] == '+':
            s = s[:-1]
        try:
            s = float(s)
        except BaseException:
            s = 0
        return s

#преобразование HomeFacts
def convHomeFacts(s):
    s = s.replace('None', 'null')
    s = s.replace("'", '"')
    try:
        s = json.loads(s)
    except BaseException:
        s = 'NONE'
    return s

#парсинг словаря для заполнения новых колонок
def parseHomeFacts(tmp_dict, name):
    for i in range (len(tmp_dict['atAGlanceFacts'])):
        if tmp_dict['atAGlanceFacts'][i]['factLabel'] == name:
            return tmp_dict['atAGlanceFacts'][i]['factValue']

#парсинг текстовых значений в бинарное
def convYesNo(s):
    if not s:
        return True

#преобразование площади
def convSqFt(s):   
    s = s.replace('nan','').strip()
    s = s.replace('nan nan','').strip()
    s = s.replace('0.0 ','').strip()
    s = s.replace(' 0.0','').strip()
    s = s.strip()
    if s.find(' ') > 0:
        try:
            s1 = s
            tmp = s.split(' ')
            s = float(tmp[0]) + float(tmp[1])
        except BaseException:
            print('ERROR_split_' + s1 + '_')
    try:
        float(s)
    except BaseException:
        s = 0
    return s

#преобразуем статус - убираем редкие статусы
def convStatus(s):
    try:
        s = s.lower()
    except BaseException:
        s = ''
    if not s in ['for sale', 'active', 'foreclosure', 'new construction', 'pending', 'pre-foreclosure']:
        s = None
    return s

# %%
#загрузка датасета
df = pd.read_csv('data 2.csv', encoding='UTF-8')
start_size = df.shape[0]
#первичная обработка
df = df.dropna(axis=0, subset=['sqft'])
df['target'] = df['target'].fillna(0)
df['fireplace'] = df['fireplace'].fillna(False)
df['target'] = df['target'].apply(lambda x: convTarget(x)) #цена в число
df = df[(df['target'] != 0)]

#преобразуем и чистим не валидные JSON в поле homeFacts
df = df[df['homeFacts'].apply(lambda x: x.count("'")).isin([56,58])]
df['homeFacts'] = df['homeFacts'].apply(lambda x: convHomeFacts(x))
df = df[df['homeFacts'] != 'NONE']

#добавляем новые колонки на основе homeFacts
new_lables = []
tmp_dict = df['homeFacts'][0] 
for i in range (len(tmp_dict['atAGlanceFacts'])):
    new_lables.append(tmp_dict['atAGlanceFacts'][i]['factLabel']) #названия колонок
for item in new_lables:
    df[item] = df['homeFacts'].apply(lambda x: parseHomeFacts(x,item)) #добавляем в датасет
df = df.drop(columns=['homeFacts'])

#преобразуем sqft - обединяем с lotsize
# df['sqft'] = df['sqft'].apply(lambda x: convTarget(x))
# df['lotsize'] = df['lotsize'].apply(lambda x: convTarget(x))
# df['SqFt'] = (df['sqft'].astype(str) +' '+ df['lotsize'].astype(str))
# df['SqFt'] = df['SqFt'].apply(lambda x: convSqFt(x))
df = df.drop(columns=['sqft','lotsize']) #не проверил - значений мало для анализа

#fireplace к единому виду
df['fireplace'] = df['fireplace'].apply(lambda x: convYesNo(x))

#PrivatePool к единому виду - собираем из двух - дропаем исходные
df['Private Pool'] = df['PrivatePool'].astype(str) + df['private pool'].astype(str)
df['Private Pool'] = df['Private Pool'].apply(lambda x: None if x == 'nannan' else 'yes')
df = df.drop(columns=['PrivatePool','private pool'])

#колонка status
df['status'] = df['status'].astype(str).apply(lambda x: convStatus(x))
df = df.dropna(axis=0, subset=['status'])

current_size=df.shape[0]
loss_size= start_size - current_size

# %%
df['propertyType'].value_counts().index.tolist()
# Out:
# ['single-family home',
#  'Single Family',
#  'Single Family Home',
#  'condo',
#  'townhouse',
#  'Land',
#  'multi-family',
#  'Condo/Townhome/Row Home/Co-Op',
#  'Traditional',
#  'Condo',
#  'lot/land',
#  'Townhouse',
#  'coop',
#  'Ranch',
#  'High Rise',
#  'Single Detached, Traditional',
#  'Contemporary',
#  'mobile/manufactured',
#  'Detached, One Story',
#  'Multi Family',
#  'Multi-Family Home',
#  'Colonial',
#  'Contemporary/Modern',
#  '1 Story',
#  'Single Detached',
#  'Mfd/Mobile Home',
#  '2 Stories',
#  'Detached, Two Story',
#  'Mobile / Manufactured',
#  'Transitional',
#  'Florida',
#  'One Story',
#  'Apartment',
#  'Bungalow',
#  'Farms/Ranches',
#  'apartment',
#  'Garden Home',
#  'Two Story',
#  'Spanish/Mediterranean',
#  'Cape Cod',
#  'Other Style',
#  'Condo/Townhome, Traditional',
#  '2 Story',
#  'Craftsman',
#  'Contemporary/Modern, Traditional',
#  '2 Stories, Traditional',
#  'Cooperative',
#  'Condo/Townhome',
#  'Condo/Townhome, Contemporary/Modern',
#  'SingleFamilyResidence',
#  'Other',
#  'Single Detached, Contemporary/Modern',
#  '1 Story, Traditional',
#  'Ranch, Traditional',
#  'Mediterranean',
#  'Traditional, Transitional',
#  'Custom',
#  'Urban Contemporary',
#  'Federal',
#  'Cluster Home',
#  '2 Stories, Contemporary',
#  'Split-Level',
#  'Victorian',
#  'Condominium (Single Level), Contemporary',
#  'Other (See Remarks)',
#  'Condominium (Single Level)',
#  'Single Detached, Ranch',
#  'Ranch, One Story',
#  'Detached, Ranch, One Story',
#  'Townhouse, Modern',
#  'Low-Rise (1-3 Stories)',
#  '1 Story, Contemporary',
#  'Detached',
#  'Spanish',
#  'Key West',
#  'Tri-Level',
#  'Condo/Unit',
#  ' ',
#  'Tudor',
#  'Penthouse',
#  'Detached, Two Story, Spanish/Mediterranean',
#  'Bungalow, Cape Cod',
#  'Cottage',
#  '1 Story with Basement',
#  'Single Detached, Craftsman',
#  'A-Frame',
#  'Split Level',
#  'Fourplex',
#  'Straight Thru',
#  'Detached, One Story, Spanish/Mediterranean',
#  'Mid-Century Modern',
#  'Single Detached, Other (See Remarks)',
#  'Florida, Ranch',
#  'High Rise, Penthouse',
#  'Santa Barbara/Tuscan',
#  'Single Detached, Ranch, Traditional',
#  'Rancher',
#  'Other Style, Traditional',
#  'Custom, Florida',
#  'Mediterranean, Traditional',
#  'Multiple Occupancy',
#  'Multiplex',
#  'Farmhouse',
#  'Colonial, Traditional',
#  'Single Detached, Contemporary/Modern, Traditional',
#  'French',
#  'English',
#  'High Rise, Split-Level',
#  '2 Stories with Basement',
#  '1 Story, Ranch',
#  'Single Detached, Mid-Century Modern',
#  'High-Rise (8+ Stories)',
#  '1 Story, Historic/Older',
#  'French, Traditional',
#  '2 Stories, Mediterranean',
#  'Georgian',
#  'Single Detached, Tudor',
#  'Florida, Traditional',
#  'Mid-Rise',
#  'Detached, Ranch',
#  'Contemporary, Florida',
#  'Attached or 1/2 Duplex, Contemporary/Modern',
#  'Condominium (Single Level), Modern',
#  'Contemporary, Modernist',
#  'European',
#  'Contemporary/Modern, Mediterranean',
#  'Modern',
#  'Elevated',
#  'Bi-Level',
#  'Beaux Arts',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern',
#  'Condo/Townhome, Contemporary/Modern, Traditional',
#  'Condo/Townhome, Hi-Rise, Traditional',
#  'Split Level, Traditional',
#  'Attached or 1/2 Duplex, Traditional',
#  'Single Detached, A-Frame',
#  'One Story, Spanish/Mediterranean',
#  'unknown',
#  'Cape',
#  'Duplex',
#  'Townhouse, Contemporary',
#  'French Provincial',
#  'High Rise, Ranch',
#  'Modernist',
#  'Condo/Townhome, Other (See Remarks)',
#  'Two Story, Spanish/Mediterranean',
#  'Garden Apartment',
#  'Condominium (Single Level), Traditional',
#  'Single Detached, Mediterranean',
#  'Contemporary, Custom',
#  'Craftsman, Transitional',
#  'Contemporary, Traditional',
#  'Farm House',
#  'Contemporary, Ranch',
#  'Historical',
#  'Raised Ranch',
#  'Cluster Home, Garden Home',
#  'Loft',
#  'Multi-Level, Modern',
#  'Art Deco',
#  'Manufactured House, Ranch, One Story',
#  'Coach/Carriage',
#  'Custom, Elevated',
#  'Less Than 4 Floors',
#  'Garden/Zero Lot Line, Single Detached, Traditional',
#  'Multi-Level',
#  'Georgian, Traditional',
#  'Charleston',
#  'Manufactured House, Manufactured Home',
#  'Split-Entry',
#  'Contemporary, Modernist, Transitional',
#  'Single Detached, French',
#  'Mountain Contemporary',
#  'Contemporary/Modern, Other Style',
#  '2 Stories, Historic/Older',
#  'Manufactured House, Ranch, One Story, Manufactured Home',
#  'English, Traditional',
#  '2 Stories, Texas Hill Country',
#  'Detached, Spanish/Mediterranean',
#  '2 Stories, Contemporary, Traditional',
#  'Craftsman, Traditional',
#  '3+ Stories',
#  '2 Story, Craftsman',
#  'Single Detached, Craftsman, Traditional',
#  'Elevated, Key West',
#  'Single Detached, Contemporary/Modern, Mid-Century Modern',
#  'Coastal',
#  'High-Rise',
#  '1 Story with Basement, Craftsman',
#  'Multi Generational, Traditional',
#  'Bungalow, Craftsman',
#  'Condo/Townhome, Hi-Rise',
#  'Mid-Rise (4-7 Stories)',
#  'Florida, Spanish/Mediterranean',
#  'Garden/Zero Lot Line, Single Detached, Contemporary/Modern',
#  '3+ Stories, Contemporary',
#  'Colonial, Contemporary/Modern',
#  'Garden/Zero Lot Line, Traditional',
#  'Bilevel',
#  'Bungalow, Ranch',
#  'Contemporary/Modern, Split Level',
#  '1 Story, Texas Hill Country',
#  'Bungalow, Traditional',
#  'Flat',
#  'Traditional, Victorian',
#  '1 Story, Ranch, Traditional',
#  'Contemporary/Modern, Other Style, Traditional',
#  'Condominium (2 Levels)',
#  'Detached, Patio Home, Two Story',
#  'Garden Home, High Rise',
#  'Florida, Key West',
#  'Patio',
#  '1 1/2 Story with Basement',
#  'Courtyard',
#  'Ranch, Transitional',
#  'Contemporary, Modern',
#  'Territorial/Santa Fe',
#  'Townhome Style',
#  'Condo/Townhome, Mediterranean',
#  '1 Story, Craftsman',
#  'Contemporary/Modern, French',
#  '4+ Floors',
#  'Triplex',
#  'Attached, Ranch',
#  '10+ Units',
#  '2 Story, Traditional',
#  'Colonial, Tudor',
#  'YES',
#  '1 Story, Mediterranean',
#  '1 Story, Historic/Older, Traditional',
#  '1 Story, Other (See Remarks)',
#  'Cluster Home, Split-Level',
#  'Two Story, Low Rise',
#  'Single Detached, Colonial',
#  '2 Stories with Basement, Craftsman',
#  'Contemporary/Modern, Ranch',
#  'Garden Home, Split-Level',
#  'High Ranch',
#  'Contemporary, Condo/Unit',
#  'Spanish, Traditional',
#  'Detached, Tri-Level',
#  'Attached, End Unit',
#  'Attached',
#  'Custom, Spanish/Mediterranean',
#  'Historical/Conservation District, Single Detached, Craftsman',
#  'Contemporary, Townhouse',
#  '2 Story, Contemporary',
#  'Single Wide',
#  'Historical/Conservation District, Single Detached, Tudor',
#  'Single Detached, French, Traditional',
#  'Detached, Two Story, Split-Level',
#  'Cabin',
#  'Cape Cod, Colonial',
#  'Townhouse, Northwestern Contemporary',
#  'Attached or 1/2 Duplex',
#  'Contemporary/Modern, French, Other Style, Traditional',
#  '4-Plex',
#  'Custom, Elevated, Key West',
#  'Townhouse, Traditional',
#  '2 Stories with Basement, Modern',
#  '1 Story with Basement, Northwestern Contemporary',
#  'Single Detached, Other (See Remarks), Traditional',
#  '1 1/2 Story with Basement, Craftsman',
#  'Low Rise',
#  'Townhouse, Townhouse',
#  'Split (3 Level)',
#  '1 Story with Basement, Contemporary',
#  'Bungalow, Contemporary',
#  '1 Story/Ranch',
#  'Townhouse, Craftsman',
#  'Detached, Split-Level',
#  'Detached, One Story, Split-Level',
#  'Single Detached, Mid-Century Modern, Traditional',
#  'Cluster Home, Ranch',
#  'Single Detached, Mid-Century Modern, Ranch',
#  'High Rise, Multiplex, Ranch',
#  'Farm House, Modernist',
#  'Condo/Townhome, Mediterranean, Traditional',
#  'Colonial, Victorian',
#  'Coastal Modern',
#  'Split',
#  'Condo/Townhome, Contemporary/Modern, Loft',
#  'Bungalow, Florida',
#  '2 Story, Northwestern Contemporary',
#  'High Rise, Spanish/Mediterranean',
#  'Manufactured Home, Mobile Home, Ranch',
#  'Detached, One Story, Two Story',
#  'Contemporary/Modern, Ranch, Traditional',
#  'Elevated, Florida, Key West',
#  'Loft/Balcony',
#  '1 Story, Spanish',
#  'Custom, Florida, Ranch',
#  'Condo/Townhome, Mid-Century Modern',
#  '1 Story, Contemporary, Traditional',
#  '2 Stories, Spanish',
#  'Side-by-Side',
#  'Farmhouse/National Folk',
#  'Single Detached, Prairie',
#  '3 Story',
#  'Detached, Duplex',
#  '2 Stories with Basement, Tudor',
#  'Detached, Patio Home, One Story',
#  'Single Detached, Traditional, Tudor',
#  'One Story, Duplex',
#  'Condo/Townhome, Loft',
#  '2 Story, Modern',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern, Traditional',
#  'Condominium (3+ Levels)',
#  'Tudor/Provincial',
#  'Detached, Ranch, Two Story',
#  'Contemporary, Spanish/Mediterranean',
#  'Contemporary/Modern, High Rise',
#  'AirLite',
#  'Contemporary, Transitional',
#  'Lake House, Single Detached, Traditional',
#  'Quad Level',
#  'Attached, End Unit, Ranch',
#  '1 Story with Basement, Traditional',
#  'Condo/Townhome, Tudor',
#  'French Province',
#  '1 1/2 Story',
#  'Spanish/Mediterranean, Traditional',
#  'Contemporary, Florida, Ranch',
#  'Bilevel, Contemporary',
#  'Arts & Crafts',
#  'Manufactured Single-Wide',
#  'Penthouse, Split-Level',
#  'Elevated, Florida',
#  '2 Stories, Traditional, Texas Hill Country',
#  '2 Stories, Contemporary, Texas Hill Country',
#  'Custom, Traditional',
#  'Split (5+ Level)',
#  'Condo/Townhome, Contemporary/Modern, Mid-Century Modern',
#  'Less Than 4 Floors, Contemporary',
#  '5-9 Units',
#  'Split Foyer',
#  'Contemporary/Modern, Split Level, Traditional',
#  'Contemporary, Elevated',
#  'Manufactured House, Traditional, Manufactured Home',
#  'Miscellaneous',
#  'Multi-Level, Northwestern Contemporary',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern, Loft',
#  '2 Stories, Split Level, Traditional',
#  'Split (4 Level)',
#  'Single Detached, Mediterranean, Traditional',
#  'Split Level, Townhouse',
#  'Farm/Ranch House, Ranch',
#  'Single Detached, Contemporary/Modern, Other (See Remarks)',
#  'Colonial, Contemporary',
#  'Garden Home, Spanish/Mediterranean',
#  'Cluster Home, High Rise',
#  'Contemporary/Modern, French, Traditional',
#  '2 Stories, Other (See Remarks)',
#  'Other Style, Ranch, Traditional',
#  'End Unit, Townhouse',
#  'One Story, Split-Level',
#  'Split-Level, Tri-Level',
#  'Other Style, Ranch',
#  'Ranch, Spanish',
#  'Historical/Conservation District, Craftsman',
#  'Craftsman, Other',
#  'Contemporary, Ranch, Traditional',
#  'Contemporary, Spanish',
#  '1 Story, Historic/Older, Craftsman',
#  'High Rise, Multiplex',
#  'Contemporary, Loft',
#  '2 Story, Other (See Remarks)',
#  '2 Stories with Basement, Contemporary',
#  'Contemporary, Mid-Century Modern',
#  'Historical/Conservation District, Single Detached, Traditional',
#  'Cluster Home, Colonial',
#  'Garden Home, Tri-Level',
#  'Bungalow, Historical',
#  'Condo/Townhome, Hi-Rise, Resort Property, Vacation Home, Contemporary/Modern, Other (See Remarks)',
#  'Mediterranean, Spanish',
#  'Two Story, Split-Level',
#  'Mid-Century Modern, Ranch',
#  '1 Story, Traditional, Texas Hill Country',
#  'Hi-Rise',
#  '1 Story, Contemporary, Ranch',
#  '1 Story, Ranch, Traditional, Texas Hill Country',
#  'Multi-Level, Craftsman',
#  'Mid-Century Modern, Traditional',
#  '2 Stories, Split Level',
#  'Contemporary/Modern, English',
#  'Step Ranch',
#  'Contemporary, Elevated, Florida',
#  'Bungalow, Craftsman, Historical',
#  'Bungalow, Ranch, Traditional',
#  '2 Stories, Historic/Older, Traditional',
#  'Federal, Contemporary',
#  'Hi-Rise, Traditional',
#  'Multiplex, Ranch',
#  'Arts & Crafts, Bungalow',
#  'Condo/Townhome, Hi-Rise, Resort Property, Vacation Home, Contemporary/Modern',
#  'Villa',
#  'Single Detached, English',
#  'Contemporary, Courtyard',
#  'Contemporary, Other',
#  'A-Frame, Traditional',
#  'Single Detached, A-Frame, Traditional',
#  '2 Stories, Colonial',
#  'Condo/Townhome, Hi-Rise, Other (See Remarks)',
#  'Manufactured Home, One Story',
#  'Conventional',
#  'Cape, Contemporary',
#  'Multi-Level, Colonial',
#  'Contemporary, High Rise',
#  'Hi-Rise, Contemporary/Modern',
#  'Condominium (Single Level), Craftsman',
#  '4+ Floors, Contemporary',
#  'Studio',
#  'Attached or 1/2 Duplex, Other (See Remarks)',
#  '2 Stories, Contemporary, Mediterranean',
#  'Split-Entry, Northwestern Contemporary',
#  'Single Detached, Contemporary/Modern, Mediterranean',
#  'Condo/Townhome, French',
#  'Custom, Elevated, Florida',
#  'Florida, Ranch, Traditional',
#  'Less Than 4 Floors, Ranch',
#  'Colonial, Georgian',
#  'Split-Entry, Traditional',
#  'Craftsman, Ranch, Transitional',
#  'Single Detached, Mid-Century Modern, Ranch, Traditional',
#  'Coach/Carriage, Cluster Home',
#  '2 Stories, Spanish, Mediterranean',
#  'Attached, Ranch, Side by Side',
#  'Farm/Ranch',
#  'Craftsman, Ranch',
#  'French, Other Style, Traditional',
#  'Multi-Level, Contemporary',
#  'Tri-Level, Craftsman',
#  'Modernist, Transitional',
#  'Single Detached, Split Level',
#  'Bungalow, Cape Cod, Colonial',
#  '2 Stories with Basement, Traditional',
#  'End Unit',
#  'Condo/Townhome, Colonial',
#  'Contemporary, Converted Dwelling',
#  'Condominium (3+ Levels), Contemporary',
#  'Ranch, Traditional, Transitional',
#  'Single Detached, Early American, Traditional',
#  '1 Story, Split Level',
#  'Tri-Level, Modern',
#  'Manufactured Home',
#  'Attached or 1/2 Duplex, Condo/Townhome, Contemporary/Modern',
#  'Colonial, Transitional',
#  'Texas Hill Country',
#  'Single Detached, Contemporary/Modern, Mid-Century Modern, Traditional',
#  'Contemporary, Federal',
#  'Courtyard, Townhouse',
#  'Custom, Elevated, Spanish/Mediterranean',
#  'Detached, Manufactured Home',
#  'Custom, Other',
#  '2 Stories, Spanish, Historic/Older',
#  'Carriage House',
#  'Bungalow, Key West',
#  'Single Detached, Early American',
#  'Coastal Beach Home',
#  'New Englander',
#  'Houseboat',
#  'Attached or 1/2 Duplex, Mediterranean',
#  'Colonial, Custom',
#  '1 Story, Ranch, Texas Hill Country',
#  'Contemporary, Split Level',
#  'Multi-Level, New Englander',
#  'Farm House, Ranch',
#  'Condominium (Single Level), Other (See Remarks)',
#  'Multi Generational',
#  'Ranch, Two Story',
#  'Attached or 1/2 Duplex, Contemporary/Modern, Traditional',
#  '1 Story, Traditional, Other (See Remarks)',
#  'Contemporary/Modern, Multiplex',
#  'Attached or 1/2 Duplex, Condo/Townhome',
#  '2 Stories, Historic/Older, Traditional, Texas Hill Country',
#  'Carriage',
#  '1 1/2 Story with Basement, Cape Cod',
#  'Bungalow, Historical, Traditional',
#  'Contemporary, Loft with Bedrooms',
#  'Contemporary/Modern, Spanish',
#  'Historic/Older',
#  'Single Detached, Contemporary/Modern, Ranch',
#  '1 Story, Historic/Older, Traditional, Craftsman',
#  'One Level Unit',
#  'Modern, Traditional',
#  'A-Frame, Contemporary',
#  'Condo/Townhome, Split Level',
#  'Elevated, Spanish/Mediterranean',
#  'Coastal, Traditional',
#  'Attached, Attached Duplex, End Unit',
#  'Modern, Ranch',
#  'Mediterranean, Other Style, Spanish',
#  'Other, Duplex',
#  '2 Stories, Contemporary, Craftsman',
#  'Arts & Crafts, Traditional',
#  'Courtyard, Key West, Spanish/Mediterranean',
#  '2 Stories, Contemporary, Spanish, Traditional, Mediterranean',
#  'Condo/Townhome, Spanish, Split Level',
#  'Tri-Level, Northwestern Contemporary',
#  'Manufactured Double-Wide',
#  'Arts & Crafts, Craftsman',
#  'Single Detached, Contemporary/Modern, Split Level',
#  'Attached or 1/2 Duplex, Condo/Townhome, Colonial, English, Traditional',
#  '1 1/2 Story, Craftsman',
#  'Florida, Historical',
#  'Colonial, Historical',
#  'Contemporary, Straight Thru',
#  'Modern, Transitional',
#  'Other Arch (See Remarks)',
#  'Contemporary, Custom, Florida',
#  'Single Detached, Contemporary/Modern, Tudor',
#  'Garden/Zero Lot Line, Single Detached',
#  'Bungalow, Craftsman, Cottage',
#  '2 Stories, Contemporary, Traditional, Texas Hill Country',
#  'Condo/Townhome, Hi-Rise, Mediterranean',
#  'Bi-Level, Split-Level',
#  'Detached, Manufactured Home, One Story',
#  'Colonial, Craftsman',
#  'Manufactured House, Coach/Carriage, Manufactured Home',
#  'Condo/Townhome, Contemporary/Modern, French',
#  'Colonial, Split-Level',
#  'Condo/Townhome, Hi-Rise, Mid-Century Modern',
#  'Bungalow, Spanish/Mediterranean',
#  '2-Story',
#  'Single Detached, English, Traditional',
#  '2 Stories, Colonial, Ranch',
#  '1 Story, Contemporary, Texas Hill Country',
#  '2 Stories with Basement, Northwestern Contemporary',
#  'Federal, Colonial',
#  'Cluster Home, Tri-Level',
#  'Single Detached, Craftsman, Early American',
#  'Loft with Bedrooms',
#  'Penthouse, Spanish/Mediterranean',
#  'Patio Home, Two Story',
#  'Condominium (Single Level), Spanish/Southwestern',
#  'Cape Cod, Traditional',
#  'Florida, Patio, Ranch',
#  'Contemporary/Modern, Other Style, Ranch, Traditional',
#  'Contemporary, Flat, Transitional',
#  'Condo/Townhome, Contemporary/Modern, Spanish',
#  'Custom, Ranch',
#  'Custom, Other, Spanish/Mediterranean',
#  'Old World',
#  'Single Detached, Colonial, Traditional',
#  'Farm/Ranch House',
#  'Patio, Traditional',
#  '1 Story, Spanish, Mediterranean',
#  'Farmhouse, Modern',
#  'Tri-Level, Contemporary',
#  'Traditional, Williamsburg',
#  'Colonial, Farmhouse',
#  '4+ Floors, Courtyard',
#  'Cluster Home, Garden Home, Split-Level',
#  'Craftsman, Warehouse',
#  'Multi Generational, Ranch',
#  'Charleston, Transitional',
#  'Traditional, Zero-Lot Line',
#  'Custom, Florida, Spanish/Mediterranean',
#  'Elevated, Other',
#  '1 Story with Basement, Spanish/Southwestern',
#  'Other, Patio',
#  'French, Other Style',
#  'Log',
#  'Florida, Other, Spanish/Mediterranean',
#  'Attached, Townhouse',
#  'Craftsman, Traditional, Transitional',
#  'Traditional, Loft with Bedrooms',
#  'Detached, Two Story, Tri-Level',
#  'Dwelling w/Separate Living Area',
#  'Craftsman, Florida',
#  'Colonial, Ranch',
#  '2 Stories with Basement, Cape Cod',
#  'Patio Home, One Story',
#  'Contemporary, Elevated, Key West',
#  '2 Stories, Historic/Older, Craftsman',
#  'Tri-Level, Traditional',
#  'Less Than 4 Floors, Old Spanish',
#  'Contemporary, Modern Architecture',
#  'Camp',
#  '2 Stories, Spanish, Traditional',
#  'Old Style',
#  'Traditional, Federal',
#  'Condo/Townhome, Hi-Rise, Loft',
#  'Farmhouse/National Folk, Contemporary, Craftsman',
#  'Condo/Townhome, Mid-Century Modern, Traditional',
#  'Co-op, Contemporary',
#  'Hill Country',
#  'Condo/Townhome, Contemporary/Modern, Other (See Remarks)',
#  'Attached, End Unit, Ranch, Side by Side',
#  'Colonial, French',
#  '3+ Stories, Historic/Older',
#  'Mediterranean, Other Style',
#  'Log Home',
#  'Colonial, French, Traditional',
#  'Condo/Townhome, Split Level, Traditional',
#  'French, Mediterranean',
#  '1 Story, Cabin',
#  'Contemporary/Modern, Mediterranean, Spanish',
#  'Bungalow, Mid-Century Modern',
#  'Denver Square',
#  'Single Detached, Mediterranean, Spanish',
#  'Rustic Contemporary',
#  'Bungalow, Colonial',
#  'Single-Wide Mobile With Land',
#  'Single Detached, Craftsman, Early American, Traditional',
#  'European, Farmhouse',
#  'Florida, Other',
#  'French Province, Traditional',
#  'Ranch, Spanish/Mediterranean',
#  'Designated Historical Home, Single Detached, Craftsman',
#  'Attached or 1/2 Duplex, A-Frame, Contemporary/Modern, French, Traditional',
#  'Contemporary, Custom, Elevated, Florida',
#  'Traditional, Contemporary',
#  '2 Stories, Ranch',
#  'Single Detached, Split Level, Traditional',
#  'Post and Beam',
#  'Rustic',
#  'Trinity',
#  'Bungalow, Cape Cod, Ranch',
#  'Contemporary, Loft, Loft with Bedrooms',
#  'Bilevel, Traditional',
#  'Victorian/Federal',
#  'Craftsman, Bungalow',
#  'Contemporary, Craftsman',
#  'Attached or 1/2 Duplex, A-Frame, Contemporary/Modern, Traditional',
#  'Bungalow, Multi Generational',
#  'Co-op',
#  'Detached, One Story, Duplex',
#  '3+ Stories, Traditional',
#  'Modular/Prefab, Manufactured Home, Mobile Home',
#  'Single Detached, Contemporary/Modern, Craftsman',
#  'Traditional, Transitional, Williamsburg',
#  'Houseboat, Northwestern Contemporary',
#  'Condo/Townhome, Garden/Zero Lot Line, Traditional',
#  '1 Story with Basement, Modern',
#  'Single Detached, A-Frame, Craftsman',
#  'Warehouse',
#  'Flat, Walkout Lower Level',
#  'Bilevel, Loft with Bedrooms, Condo/Unit',
#  '2 Stories, Colonial, Traditional',
#  'Townhouse-Interior',
#  'Contemporary, Florida, Other',
#  'Courtyard, Spanish/Mediterranean',
#  'Dutch Colonial',
#  'Lake House, Single Detached, Mediterranean',
#  'Garden Home, Traditional',
#  'Contemporary, Custom, Ranch, Traditional',
#  'Craftsman, Transitional, Cottage',
#  'Condo/Townhome, Hi-Rise, Mediterranean, Traditional',
#  'Arts & Crafts, Bungalow, Tudor, Cottage',
#  'Historic',
#  'Traditional, Bilevel',
#  'Contemporary/Modern, Other Style, Split Level',
#  'Single Detached, Mediterranean, Split Level, Traditional',
#  '1 Story, Ranch, Historic/Older',
#  'Dwelling with Rental',
#  'Houseboat, Modern',
#  'Condo/Townhome, Hi-Rise, Historical/Conservation District, Mid-Century Modern, Traditional',
#  'French Province, Traditional, Transitional',
#  'Dutch, Contemporary',
#  'Lake House, Resort Property, Single Detached, Vacation Home, Traditional',
#  'Craftsman, Custom, Florida, Patio, Ranch',
#  '1 1/2 Story, Tudor',
#  'Condo/Townhome, Contemporary/Modern, Mediterranean, Spanish',
#  'Detached, One Story, Tri-Level',
#  '1 Story, Historic/Older, Other (See Remarks)',
#  'Contemporary, Saltbox',
#  'Bungalow, Contemporary, Florida',
#  '1 Story, Contemporary, Spanish, Traditional, Mediterranean',
#  'Duplex, Townhouse',
#  'Florida, Key West, Other',
#  'Craftsman, Farm House, Transitional',
#  'Single Detached, Contemporary/Modern, Ranch, Traditional',
#  'Cape, Other',
#  'Split Level, Contemporary, Texas Hill Country',
#  'Raised Ranch, Rancher',
#  'Cape Cod, Florida, Ranch, Traditional',
#  'Cape, Saltbox',
#  'FLORIDA STYLE',
#  'Single Detached, Colonial, English',
#  '2 Stories, Ranch, Traditional',
#  'A-Frame, Victorian/Federal',
#  'Contemporary, Loft with Bedrooms, Loft',
#  'Apartment Building, Farmhouse, Other',
#  'Ranch, Split Level',
#  'Townhouse, Zero-Lot Line',
#  'Cape Cod, Traditional, Transitional',
#  'Traditional, Cottage',
#  'Contemporary, Bungalow',
#  'Split Level, Other (See Remarks)',
#  'Traditional, Colonial, Federal',
#  'Contemporary, Craftsman, Farmhouse/National Folk',
#  'Mobile Home',
#  'Charleston, Traditional, Transitional',
#  'Straight Thru, Contemporary',
#  'Condo/Townhome, Hi-Rise, Resort Property, Contemporary/Modern',
#  'Attached, End Unit, Lower Level, Ranch',
#  'Condo/Townhome, Southwestern',
#  'Carriage, Contemporary, Ranch, Walkout Lower Level, Craftsman',
#  'Contemporary, Traditional, Transitional',
#  'Federal, Loft',
#  'Less Than 4 Floors, European',
#  '1 1/2 Story, Modern',
#  'Dutch Provincial',
#  'Attached or 1/2 Duplex, Single Detached, A-Frame, Traditional',
#  'Contemporary, Elevated, Mid-Century Modern',
#  'Chalet, Cottage',
#  'Cape Cod, Custom',
#  'Georgian, Multi Generational',
#  'Cape, Cottage',
#  'Manufactured Double-Wide, Traditional',
#  'Mediterranean, Other Style, Traditional',
#  'French, Mediterranean, Other Style',
#  'Mediterranean, Villa',
#  'Cape Cod Shingle',
#  'Chalet',
#  'Colonial, Triplex',
#  'Less Than 4 Floors, Townhouse',
#  'Other - See Remarks',
#  'Condo/Unit, Bilevel, Converted Dwelling',
#  'Custom, Florida, Key West',
#  '3+ Stories, Tudor, Historic/Older, Traditional',
#  'Cabin/Lodge, Condo/Unit',
#  'Bi-Level, Multiplex',
#  'Bungalow, Craftsman, Tudor',
#  'Traditional, Colonial',
#  'Manufactured House, Multi-Level, Manufactured Home',
#  'Cape, Log',
#  '3+ Stories, Split Level, Contemporary, Ranch',
#  '3+ Stories, Texas Hill Country',
#  'Condominium (3+ Levels), Traditional',
#  'Lake House, Single Detached, Tudor',
#  'Multi-Family',
#  'Colonial, Contemporary/Modern, Other Style, Traditional',
#  'Contemporary, Modernist, Ranch, Rustic',
#  'Contemporary, Condo/Unit, Loft with Bedrooms',
#  'Garden/Zero Lot Line, Single Detached, Craftsman',
#  'Coastal Two Story',
#  '1 1/2 Story, Contemporary',
#  'Other, Patio, Traditional',
#  'Loft, Split Level, Townhouse, Traditional',
#  'Condo/Townhome, Mediterranean, Spanish',
#  'Bi-Level, Ranch',
#  'Ranch, One Story, Duplex',
#  'Hi-Rise, Contemporary/Modern, Traditional',
#  'Apartment, Condo/Townhome',
#  'Contemporary, Custom, Ranch, Spanish/Mediterranean, Traditional',
#  'Colonial, Spanish/Mediterranean',
#  'Colonial, Cottage, Tudor',
#  'Bungalow, Other, Victorian/Federal',
#  '2 Stories, Tudor, Traditional',
#  'Modern Farmhouse',
#  'Bungalow, Contemporary, Craftsman, Custom',
#  'Historical/Conservation District, Victorian',
#  'Courtyard, Custom, Other',
#  'Cape Cod, Ranch',
#  'Ground Floor, Studio, Walkout Lower Level',
#  'Apartment, Attached or 1/2 Duplex, Condo/Townhome, Hi-Rise, Resort Property, Single Detached, Vacation Home, English, Split Level',
#  'Bungalow, Craftsman, Transitional, Cottage',
#  'Farmhouse, Historic Vintage',
#  'Colonial, Conventional',
#  'Cape, Other Style',
#  'Bungalow, Contemporary, Ranch, Traditional',
#  'Garden/Zero Lot Line, Single Detached, Contemporary/Modern, Mid-Century Modern',
#  'Apartment, Condo/Townhome, Garden/Zero Lot Line',
#  '2.5 Story',
#  'Condo/Townhome, Resort Property, Vacation Home, Contemporary/Modern',
#  'Less Than 4 Floors, 4+ Floors, Art Deco, Multi-Level',
#  'French, Ranch',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern, Studio',
#  'Less Than 4 Floors, Other Arch (See Remarks), Traditional',
#  'Single Detached, French, Other (See Remarks)',
#  'Cape, Multi-Level, Other Style',
#  'Single Detached, Contemporary/Modern, Craftsman, Mediterranean, Prairie',
#  '1 Story, Manufactured Home - Double Wide, Other (See Remarks)',
#  'Single Detached, Contemporary/Modern, Oriental, Ranch, Traditional',
#  'Multi Generational, Ranch, Tudor',
#  'Single Detached, French, Mid-Century Modern',
#  'Country English',
#  'Condo/Townhome, Vacation Home, Contemporary/Modern',
#  'Contemporary, Rustic',
#  '3+ Stories, Contemporary, Ranch, Traditional',
#  'Multi-Level, Tudor',
#  'NEW BUILD 2019, Traditional',
#  'Courtyard, Florida, Patio',
#  'French, Transitional',
#  'Garden/Zero Lot Line, Contemporary/Modern',
#  'Contemporary/Modern, Ranch, Spanish',
#  'French, Beaux Arts, Villa',
#  'Historical/Conservation District, Traditional',
#  'Garden/Zero Lot Line, Traditional, Victorian',
#  'Condo/Townhome, Split Level, Traditional, Tudor',
#  'Condominium (Single Level), Loft',
#  'Traditional, Texas Hill Country',
#  '1 Story, Tudor, A-Frame',
#  'Historical/Conservation District, Single Detached, Early American, Traditional',
#  'Lake House, Resort Property, Single Detached, Traditional',
#  'Single Detached, Prairie, Southwestern, Traditional',
#  'Contemporary, Custom, Traditional',
#  'Arts & Crafts, Bungalow, Farm House',
#  'Side-by-Side, Colonial',
#  'European, French Provincial',
#  'Single Detached, French, Traditional, Tudor',
#  'Ranch, Walkout Lower Level',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern, Southwestern',
#  'Colonial, Georgian, Traditional',
#  'Attached Duplex, End Unit',
#  'Less Than 4 Floors, Courtyard, Ranch',
#  'Rustic, Spanish, Traditional',
#  'Cottage, English',
#  'Loft, Transitional',
#  'Ranch, Territorial/Santa Fe',
#  'Contemporary, Modern, Transitional, Other (See Remarks)',
#  'Townhouse, Tri-Level',
#  'Condominium (3+ Levels), Studio',
#  'Condo/Townhome, Studio',
#  '2 Stories, Tudor, Historic/Older',
#  'Condo/Townhome, Single Detached, Split Level, Traditional',
#  'Florida, Ranch, One Story',
#  '2 Stories, Traditional, Mediterranean',
#  'Contemporary/Modern, Mediterranean, Traditional',
#  'Attached or 1/2 Duplex, Southwestern',
#  'Cape Cod, Craftsman, Custom',
#  'Bungalow, Florida, Ranch',
#  'Colonial, Other',
#  'Contemporary, Zero-Lot Line',
#  'Other Arch (See Remarks), Townhouse',
#  'Single Detached, Early American, Traditional, Tudor',
#  '3+ Stories, Contemporary, Traditional',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern, Mid-Century Modern, Other (See Remarks)',
#  'Spanish, Split Level',
#  'Condominium (2 Levels), Townhouse',
#  'Contemporary, Spanish, Santa Barbara/Tuscan, Territorial/Santa Fe',
#  'Bungalow, Tudor',
#  'Back-to-Back',
#  'Historical/Conservation District',
#  'Custom, Florida, Traditional',
#  'Transitional, Colonial',
#  'Colonial, Contemporary/Modern, English, Other Style, Traditional',
#  'Coastal II, Traditional',
#  'Lake House, Mid-Century Modern',
#  'Designated Historical Home, Colonial, Traditional, Victorian',
#  'Condominium (2 Levels), Other (See Remarks)',
#  'Manufactured (Certificate Exchange)',
#  'Arts & Crafts, Transitional',
#  'Arts & Crafts, Bungalow, Craftsman, Ranch',
#  'Contemporary/Modern, Ranch, One Story',
#  'Cape, Chalet',
#  'Designated Historical Home, Historical/Conservation District, Single Detached, Traditional',
#  'Condominium (2 Levels), Craftsman',
#  'Straight Thru, Federal',
#  'Multi-Level, Other (See Remarks)',
#  'Condominium (2 Levels), Loft',
#  'Contemporary, Condo/Unit, Bilevel',
#  'Transitional, Williamsburg',
#  'Custom, Patio, Spanish/Mediterranean',
#  'Attached Duplex, Ranch',
#  'Resort Property',
#  'Garden/Zero Lot Line, Single Detached, Victorian',
#  'Cape Cod, Contemporary, Florida, Key West',
#  'Fairway house',
#  'Farmhouse/National Folk, Craftsman, Transitional, Colonial',
#  'Less Than 4 Floors, Contemporary, Townhouse',
#  'Contemporary/Modern, French, Mediterranean',
#  'Contemporary/Modern, High Rise, Ranch',
#  'Arts & Crafts, Craftsman, Transitional',
#  'Condo/Townhome, Contemporary/Modern, Craftsman',
#  'Attached Duplex, End Unit, Ranch',
#  'Mid Century Modern',
#  'Resort Property, Single Detached, Contemporary/Modern, Mid-Century Modern',
#  'Coastal Contemporary',
#  'Single Detached, Contemporary/Modern, French',
#  'Contemporary, Farmhouse',
#  'Southern Plantation, Traditional',
#  'Rancher, Raised Ranch',
#  'Farmhouse, Multi-Family',
#  'French, Georgian, Traditional',
#  '4+ Floors, Courtyard, Traditional',
#  'Contemporary, French Provincial',
#  'Condo/Townhome, Single Detached',
#  'Cape Cod, Williamsburg, Cottage',
#  'Condo/Townhome, Mediterranean, Other (See Remarks)',
#  'Custom, Victorian',
#  'Single Detached, Contemporary/Modern, Mid-Century Modern, Prairie',
#  'Arts & Crafts, Contemporary, Craftsman, Loft, Modernist, Transitional',
#  'Traditional, Straight Thru',
#  'Contemporary/Modern, Mediterranean, Other Style',
#  'Single Detached, A-Frame, Contemporary/Modern, Traditional',
#  'Resort Property, Single Detached, Vacation Home, Contemporary/Modern, Mediterranean',
#  'Detached, Patio Home',
#  'Mediterranean, Townhouse',
#  'American 4-Square',
#  'Contemporary/Modern, Ranch, Split Level',
#  '2 Stories, Craftsman',
#  'Less Than 4 Floors, Other Arch (See Remarks)',
#  'Double-Wide Mobile With Land',
#  '1 Story, Manufactured Home - Single Wide, Manufactured Home - Double Wide',
#  'Other, Traditional',
#  'Single Detached, Prairie, Ranch, Traditional',
#  'Ranch, Rustic',
#  'English, French',
#  'Custom, Elevated, Florida, Traditional',
#  'Cabin, Cottage/Camp',
#  'Courtyard, Custom, Florida',
#  '1 Story, Spanish, Ranch, Traditional',
#  '2 Stories, Spanish, Traditional, Mediterranean',
#  'Condominium (3+ Levels), Modern',
#  'Contemporary, Texas Hill Country',
#  'Less Than 4 Floors, Multi-Level, Townhouse',
#  'Custom Home',
#  'Colonial, High Rise, Ranch',
#  'Condo/Townhome, Mediterranean, Spanish, Split Level',
#  'Less Than 4 Floors, Traditional',
#  '1 1/2 Story, Northwestern Contemporary',
#  'Lake House, Single Detached',
#  '1 1/2 Story, Traditional',
#  'Single Detached, Southwestern',
#  'Prairie',
#  'French, Ranch, Traditional',
#  'Single Detached, Mediterranean, Oriental, Other (See Remarks), Spanish',
#  'Historical/Conservation District, Single Detached, Early American',
#  'Custom, Patio',
#  '3+ Stories, Contemporary, Colonial, Traditional',
#  'Contemporary, Courtyard, Mid-Century Modern',
#  'Single Detached, Contemporary/Modern, English, French, Other (See Remarks), Ranch, Traditional',
#  'Contemporary, Elevated, Ranch',
#  'Colonial, Traditional, Transitional',
#  'Traditional, Condo/Unit',
#  'Rancher, Traditional',
#  'Farm House, Traditional',
#  'High Rise, Penthouse, Tri-Level',
#  'Traditional, Art Deco, Beaux Arts',
#  'Condo/Townhome, Hi-Rise, Contemporary/Modern, Mid-Century Modern',
#  'Mobile Manu - Double Wide, Ranch',
#  'Colonial, Contemporary/Modern, English, French, Traditional',
#  '2 Stories, Historic/Older, Victorian',
#  'Contemporary, Modern, Rustic',
#  'Bungalow, Transitional',
#  'Farm House, Transitional',
#  'Contemporary/Modern, English, French, Traditional',
#  'Farmhouse/National Folk, Contemporary',
#  'Custom, Ranch, Traditional',
#  'Bungalow, Craftsman, Transitional',
#  '1 1/2 Story with Basement, Traditional',
#  'Single Detached, Contemporary/Modern, Mediterranean, Mid-Century Modern, Other (See Remarks), Ranch, Traditional',
#  'Raised Ranch, Split Level',
#  'Ranch, Single Wide',
#  'Coach/Carriage, Garden Home',
#  'Farm/Ranch House, Single Detached, Contemporary/Modern, Ranch',
#  'Craftsman, Contemporary, Transitional',
#  '2 Stories, Colonial, Historic/Older',
#  'Farm/Ranch House, Single Detached, Early American',
#  'Art Deco, Mid Century',
#  'Bungalow, Contemporary, Other, Patio, Ranch',
#  'Colonial, English, Traditional',
#  'Garden/Zero Lot Line, Single Detached, Contemporary/Modern, Traditional',
#  '3+ Stories, Historic/Older, Traditional, Craftsman',
#  'Historic Vintage, Multi-Family',
#  'Garden/Zero Lot Line, Resort Property, Single Detached, Traditional',
#  'European, Tudor',
#  'Contemporary, Villa',
#  'Side-by-Side, Traditional',
#  'Mobile Home 1 Story',
#  'Condo/Townhome, A-Frame, Traditional',
#  'Mediterranean, Multi-Level',
#  'Florida, Patio',
#  'Charleston, Bungalow',
#  'coastal',
#  'Bungalow, Farm House, Ranch, Traditional, Cottage',
#  'Camp, Cottage',
#  'Contemporary, Colonial',
#  'Craftsman, Patio',
#  'Moorage',
#  'Penthouse, Low Rise',
#  'Contemporary, Modernist, Traditional, Transitional',
#  'Cottage/Camp',
#  'Colonial, Contemporary, Multi-Level, Other, Yurt',
#  'Farm/Ranch House, Contemporary/Modern',
#  '2 Story, Colonial',
#  'Single Detached, Contemporary/Modern, English, French, Mediterranean, Traditional',
#  '3+ Stories, Spanish',
#  'Split Level, Tri-Level',
#  'Condominium (2 Levels), Contemporary',
#  '1 Story, Split Level, Traditional',
#  'Stilt House',
#  'Attached, End Unit, Quads, Ranch',
#  'Co-op, Traditional',
#  'Condo/Townhome, Vacation Home, Contemporary/Modern, Early American, Traditional',
#  'Custom, Elevated, Other',
#  'Bi-Level, High Rise',
#  'Condo/Townhome, Single Detached, Other (See Remarks), Traditional',
#  'Colonial, Contemporary/Modern, English, French, Other Style, Traditional',
#  'Garage Storage',
#  '1 Story, Modern',
#  'Ranch, One Story, Split-Level',
#  'Florida, Mid-Century Modern',
#  'Garden/Zero Lot Line, Single Detached, Vacation Home, Mediterranean, Traditional',
#  'Colonial, Contemporary/Modern, Conventional',
#  'Colonial, Florida',
#  'Bungalow, Craftsman, Ranch',
#  ...]

# %%
def convPropertyType(s):
    s = s.lower()
    if s.find('single') > 0
        s = 'Single Family'
    if s.find('multi') > 0
        s = 'Multi Family'

# %%
#Какие-то итоговые показатели
#Показатели для модели:
#'city', 
    

print('Итоговые показатели')
print('Потеряно записей',loss_size)
# Out:
# Итоговые показатели
# Потеряно не валидных записейЖ 93376
